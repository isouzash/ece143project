# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("pollution_us_2000_2016.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746661 entries, 0 to 1746660
# Data columns (total 29 columns):
# Unnamed: 0           int64
# State Code           int64
# County Code          int64
# Site Num             int64
# Address              object
# State                object
# County               object
# City                 object
# Date Local           object
# NO2 Units            object
# NO2 Mean             float64
# NO2 1st Max Value    float64
# NO2 1st Max Hour     int64
# NO2 AQI              int64
# O3 Units             object
# O3 Mean              float64
# O3 1st Max Value     float64
# O3 1st Max Hour      int64
# O3 AQI               int64
# SO2 Units            object
# SO2 Mean             float64
# SO2 1st Max Value    float64
# SO2 1st Max Hour     int64
# SO2 AQI              float64
# CO Units             object
# CO Mean              float64
# CO 1st Max Value     float64
# CO 1st Max Hour      int64
# CO AQI               float64
# dtypes: float64(10), int64(10), object(9)
# memory usage: 386.5+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0    State Code   County Code      Site Num      NO2 Mean  \
# count  1.746661e+06  1.746661e+06  1.746661e+06  1.746661e+06  1.746661e+06
# mean   5.471414e+04  2.230907e+01  7.169381e+01  1.118214e+03  1.282193e+01
# std    3.372908e+04  1.725621e+01  7.948023e+01  2.003103e+03  9.504814e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00 -2.000000e+00
# 25%    2.575300e+04  6.000000e+00  1.700000e+01  9.000000e+00  5.750000e+00
# 50%    5.304500e+04  1.700000e+01  5.900000e+01  6.000000e+01  1.073913e+01
# 75%    8.033600e+04  4.000000e+01  9.700000e+01  1.039000e+03  1.771364e+01
# max    1.345750e+05  8.000000e+01  6.500000e+02  9.997000e+03  1.395417e+02
#
#        NO2 1st Max Value  NO2 1st Max Hour       NO2 AQI       O3 Mean  \
# count       1.746661e+06      1.746661e+06  1.746661e+06  1.746661e+06
# mean        2.541485e+01      1.173102e+01  2.389822e+01  2.612485e-02
# std         1.599963e+01      7.877501e+00  1.516280e+01  1.136974e-02
# min        -2.000000e+00      0.000000e+00  0.000000e+00  0.000000e+00
# 25%         1.300000e+01      5.000000e+00  1.200000e+01  1.787500e-02
# 50%         2.400000e+01      9.000000e+00  2.300000e+01  2.587500e-02
# 75%         3.570000e+01      2.000000e+01  3.300000e+01  3.391700e-02
# max         2.670000e+02      2.300000e+01  1.320000e+02  9.508300e-02
#
#        O3 1st Max Value  O3 1st Max Hour        O3 AQI      SO2 Mean  \
# count      1.746661e+06     1.746661e+06  1.746661e+06  1.746661e+06
# mean       3.920331e-02     1.017053e+01  3.605012e+01  1.870364e+00
# std        1.534362e-02     4.003144e+00  1.978042e+01  2.760435e+00
# min        0.000000e+00     0.000000e+00  0.000000e+00 -2.000000e+00
# 25%        2.900000e-02     9.000000e+00  2.500000e+01  2.565220e-01
# 50%        3.800000e-02     1.000000e+01  3.300000e+01  9.875000e-01
# 75%        4.800000e-02     1.100000e+01  4.200000e+01  2.325000e+00
# max        1.410000e-01     2.300000e+01  2.180000e+02  3.216250e+02
#
#        SO2 1st Max Value  SO2 1st Max Hour        SO2 AQI       CO Mean  \
# count       1.746661e+06      1.746661e+06  873754.000000  1.746661e+06
# mean        4.492185e+00      9.664906e+00       7.115945  3.682177e-01
# std         7.679866e+00      6.731228e+00      11.937473  3.140231e-01
# min        -2.000000e+00      0.000000e+00       0.000000 -4.375000e-01
# 25%         8.000000e-01      5.000000e+00       1.000000  1.834580e-01
# 50%         2.000000e+00      8.000000e+00       3.000000  2.926250e-01
# 75%         5.000000e+00      1.400000e+01       9.000000  4.666670e-01
# max         3.510000e+02      2.300000e+01     200.000000  7.508333e+00
#
#        CO 1st Max Value  CO 1st Max Hour         CO AQI
# count      1.746661e+06     1.746661e+06  873338.000000
# mean       6.201067e-01     7.875026e+00       5.996595
# std        6.439361e-01     7.978844e+00       5.851836
# min       -4.000000e-01     0.000000e+00       0.000000
# 25%        2.920000e-01     0.000000e+00       2.000000
# 50%        4.000000e-01     6.000000e+00       5.000000
# 75%        8.000000e-01     1.300000e+01       8.000000
# max        1.990000e+01     2.300000e+01     201.000000

# %%
df.head(5)
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#    Date Local          NO2 Units  ...   SO2 1st Max Value  SO2 1st Max Hour  \
# 0  2000-01-01  Parts per billion  ...                 9.0                21
# 1  2000-01-01  Parts per billion  ...                 9.0                21
# 2  2000-01-01  Parts per billion  ...                 6.6                23
# 3  2000-01-01  Parts per billion  ...                 6.6                23
# 4  2000-01-02  Parts per billion  ...                 3.0                22
#
#    SO2 AQI           CO Units   CO Mean  CO 1st Max Value  CO 1st Max Hour  \
# 0     13.0  Parts per million  1.145833               4.2               21
# 1     13.0  Parts per million  0.878947               2.2               23
# 2      NaN  Parts per million  1.145833               4.2               21
# 3      NaN  Parts per million  0.878947               2.2               23
# 4      4.0  Parts per million  0.850000               1.6               23
#
#    CO AQI  MAX_AQI   EPA
# 0     NaN     46.0  Good
# 1    25.0     46.0  Good
# 2     NaN     46.0  Good
# 3    25.0     46.0  Good
# 4     NaN     34.0  Good
#
# [5 rows x 31 columns]

# %%
NO2 = ['NO2 Units','NO2 Mean','NO2 1st Max Value','NO2 1st Max Hour','NO2 AQI']

# %%
O3 = ['O3 Units','O3 Mean','O3 1st Max Value','O3 1st Max Hour','O3 AQI']

# %%
CO = ['CO Units','CO Mean','CO 1st Max Value','CO 1st Max Hour','CO AQI']

# %%
SO2 = ['SO2 Units','SO2 Mean','SO2 1st Max Value','SO2 1st Max Hour','SO2 AQI']

# %%
#df.State.groupby(df.State).count()

# %%
CA_df =  df.loc[df.State == 'California']

# %%
SD_df = df.loc[df.County == "San Diego"]

# %% [markdown]
# # Air Quality Index (AQI) Basics, EPA
# https://cfpub.epa.gov/airnow/index.cfm?action=aqibasics.aqi <br>
# 0 to 50	Good
# 51 to 100	Moderate
# 101 to 150	Unhealthy for Sensitive Groups
# 151 to 200	Unhealthy
# 201 to 300	Very Unhealthy
# 301 to 500	Hazardous

# %%
NO2_AQI = df['NO2 AQI'].values
NO2_AQI.reshape(1,1746661)
# Out:
# array([[46, 46, 46, ...,  1,  1,  1]], dtype=int64)

# %%
O3_AQI = df['O3 AQI'].values
O3_AQI.reshape(1,1746661)
# Out:
# array([[34, 34, 34, ..., 44, 44, 44]], dtype=int64)

# %%
CO_AQI = df['CO AQI'].values
CO_AQI.reshape(1,1746661)
# Out:
# array([[nan, 25., nan, ...,  1., nan,  1.]])

# %%
SO2_AQI = df['SO2 AQI'].values
SO2_AQI.reshape(1,1746661)
# Out:
# array([[13., 13., nan, ...,  0., nan, nan]])

# %%
all_air = np.vstack((NO2_AQI,O3_AQI,CO_AQI,SO2_AQI))
all_air
# Out:
# array([[46., 46., 46., ...,  1.,  1.,  1.],
#        [34., 34., 34., ..., 44., 44., 44.],
#        [nan, 25., nan, ...,  1., nan,  1.],
#        [13., 13., nan, ...,  0., nan, nan]])

# %%
all_air = np.nan_to_num(all_air)

# %%
max_AQI = np.nanmax(all_air, axis = 0)

# %%
df['MAX_AQI'] = pd.DataFrame(max_AQI)

# %%
df['EPA'] = 'm'

# %%
df.loc[(df.MAX_AQI<=50.0) & (df.MAX_AQI>=0.0), ['EPA']] = 'Good'
df.loc[(df.MAX_AQI>50.0) & (df.MAX_AQI<=100.0), ['EPA']] = 'Moderate'
df.loc[(df.MAX_AQI>100.0) & (df.MAX_AQI<=150.0), ['EPA']] = 'Unhealthy for Sensitive Groups'
df.loc[(df.MAX_AQI>150.0) & (df.MAX_AQI<=200.0), ['EPA']] = 'Unhealthy'
df.loc[(df.MAX_AQI>200.0) & (df.MAX_AQI<=300.0), ['EPA']] = 'Very Unhealthy'
df.loc[(df.MAX_AQI>300.0) & (df.MAX_AQI<=500.0), ['EPA']] = 'Hazardous'

# %%
df.groupby(['EPA'])['EPA'].count()
# Out:
# EPA
# Good                              1482671
# Moderate                           225287
# Unhealthy                            3722
# Unhealthy for Sensitive Groups      34707
# Very Unhealthy                        274
# Name: EPA, dtype: int64

# %%
Year = df['Date Local'].values

# %%
len(Year)
# Out:
# 1746661

# %%
Year = np.nan_to_num(Year)

# %%
year=[]
for element in Year:
    year.append(int(element[:4]))

# %%
print(year[:5])
# Out:
# [2000, 2000, 2000, 2000, 2000]

# %%
len(year)
# Out:
# 1746661

# %%
df['Year'] = pd.DataFrame(year)

# %%
df.head(5)
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#    Date Local          NO2 Units  ...   SO2 1st Max Hour  SO2 AQI  \
# 0  2000-01-01  Parts per billion  ...                 21     13.0
# 1  2000-01-01  Parts per billion  ...                 21     13.0
# 2  2000-01-01  Parts per billion  ...                 23      NaN
# 3  2000-01-01  Parts per billion  ...                 23      NaN
# 4  2000-01-02  Parts per billion  ...                 22      4.0
#
#             CO Units   CO Mean CO 1st Max Value  CO 1st Max Hour  CO AQI  \
# 0  Parts per million  1.145833              4.2               21     NaN
# 1  Parts per million  0.878947              2.2               23    25.0
# 2  Parts per million  1.145833              4.2               21     NaN
# 3  Parts per million  0.878947              2.2               23    25.0
# 4  Parts per million  0.850000              1.6               23     NaN
#
#    MAX_AQI   EPA  Year
# 0     46.0  Good  2000
# 1     46.0  Good  2000
# 2     46.0  Good  2000
# 3     46.0  Good  2000
# 4     34.0  Good  2000
#
# [5 rows x 32 columns]

# %%
df.groupby(['State','Year'])['MAX_AQI'].mean()
# Out:
# State       Year
# Alabama     2013    24.806452
#             2014    37.961857
#             2015    37.700000
#             2016    39.667785
# Alaska      2014    26.030726
#             2015    27.779014
# Arizona     2000    55.186576
#             2001    46.837466
#             2002    48.813850
#             2003    47.957206
#             2004    44.662928
#             2005    46.649463
#             2006    48.315545
#             2007    45.216491
#             2008    45.281213
#             2009    42.639829
#             2010    42.190638
#             2011    43.645541
#             2012    45.563530
#             2013    46.919552
#             2014    48.184250
#             2015    47.165928
#             2016    40.023529
# Arkansas    2007    36.928571
#             2008    33.534153
#             2009    32.838356
#             2010    37.711806
#             2011    36.945205
#             2012    38.645933
#             2013    36.995890
#                       ...
# Utah        2013    51.108652
#             2014    44.757962
#             2015    49.375494
#             2016    43.142857
# Virginia    2000    42.270228
#             2006    41.345380
#             2007    44.717287
#             2008    39.482830
#             2009    35.472949
#             2010    46.948830
#             2011    43.934231
#             2012    41.299703
#             2013    36.411797
#             2014    39.238474
#             2015    39.967700
#             2016    30.216667
# Washington  2013    27.891892
#             2014    36.285714
#             2015    30.482143
#             2016    30.379310
# Wisconsin   2006    33.870690
#             2007    27.919355
# Wyoming     2007    41.576177
#             2008    39.533762
#             2011    39.742475
#             2012    40.872222
#             2013    41.516039
#             2014    44.859609
#             2015    43.015785
#             2016    41.133333
# Name: MAX_AQI, Length: 496, dtype: float64

# %%
df_annual=df.groupby(['State','Year'])['MAX_AQI'].mean()

# %%
df_annual=pd.DataFrame({'MAX_AQI' : df.groupby(['State','Year'])['MAX_AQI'].mean()}).reset_index()

# %%
df_annual.head(5)
# Out:
#      State  Year    MAX_AQI
# 0  Alabama  2013  24.806452
# 1  Alabama  2014  37.961857
# 2  Alabama  2015  37.700000
# 3  Alabama  2016  39.667785
# 4   Alaska  2014  26.030726

# %%
df_annual['EPA'] = 'm'

# %%
df_annual.loc[(df.MAX_AQI<=50.0) & (df_annual.MAX_AQI>=0.0), ['EPA']] = 'Good'
df_annual.loc[(df.MAX_AQI>50.0) & (df_annual.MAX_AQI<=100.0), ['EPA']] = 'Moderate'
df_annual.loc[(df.MAX_AQI>100.0) & (df_annual.MAX_AQI<=150.0), ['EPA']] = 'Unhealthy for Sensitive Groups'
df_annual.loc[(df.MAX_AQI>150.0) & (df_annual.MAX_AQI<=200.0), ['EPA']] = 'Unhealthy'
df_annual.loc[(df.MAX_AQI>200.0) & (df_annual.MAX_AQI<=300.0), ['EPA']] = 'Very Unhealthy'
df_annual.loc[(df.MAX_AQI>300.0) & (df_annual.MAX_AQI<=500.0), ['EPA']] = 'Hazardous'

# %%
df_annual.head(5)
# Out:
#      State  Year    MAX_AQI   EPA
# 0  Alabama  2013  24.806452  Good
# 1  Alabama  2014  37.961857  Good
# 2  Alabama  2015  37.700000  Good
# 3  Alabama  2016  39.667785  Good
# 4   Alaska  2014  26.030726  Good

# %%
df_annual.groupby(['State','Year','EPA'])['EPA'].count()
# Out:
# State       Year  EPA
# Alabama     2013  Good        1
#             2014  Good        1
#             2015  Good        1
#             2016  Good        1
# Alaska      2014  Good        1
#             2015  Good        1
# Arizona     2000  Good        1
#             2001  Good        1
#             2002  Good        1
#             2003  Good        1
#             2004  Good        1
#             2005  Good        1
#             2006  Moderate    1
#             2007  Moderate    1
#             2008  Moderate    1
#             2009  Moderate    1
#             2010  Moderate    1
#             2011  Moderate    1
#             2012  Moderate    1
#             2013  Moderate    1
#             2014  Moderate    1
#             2015  Moderate    1
#             2016  Moderate    1
# Arkansas    2007  Moderate    1
#             2008  Good        1
#             2009  Good        1
#             2010  Good        1
#             2011  Good        1
#             2012  Good        1
#             2013  Moderate    1
#                              ..
# Utah        2013  Moderate    1
#             2014  Moderate    1
#             2015  Moderate    1
#             2016  Moderate    1
# Virginia    2000  Moderate    1
#             2006  Moderate    1
#             2007  Moderate    1
#             2008  Moderate    1
#             2009  Moderate    1
#             2010  Moderate    1
#             2011  Moderate    1
#             2012  Moderate    1
#             2013  Moderate    1
#             2014  Moderate    1
#             2015  Moderate    1
#             2016  Moderate    1
# Washington  2013  Moderate    1
#             2014  Moderate    1
#             2015  Good        1
#             2016  Good        1
# Wisconsin   2006  Good        1
#             2007  Good        1
# Wyoming     2007  Good        1
#             2008  Good        1
#             2011  Good        1
#             2012  Good        1
#             2013  Good        1
#             2014  Good        1
#             2015  Good        1
#             2016  Good        1
# Name: EPA, Length: 496, dtype: int64

# %%
df_annual.loc[df_annual.EPA=='Unhealthy for Sensitive Groups']
# Out:
#           State  Year    MAX_AQI                             EPA
# 48   California  2015  43.170757  Unhealthy for Sensitive Groups
# 49   California  2016  34.179636  Unhealthy for Sensitive Groups
# 50     Colorado  2000  41.579452  Unhealthy for Sensitive Groups
# 51     Colorado  2001  50.253894  Unhealthy for Sensitive Groups
# 52     Colorado  2002  44.946593  Unhealthy for Sensitive Groups
# 53     Colorado  2003  45.677100  Unhealthy for Sensitive Groups
# 54     Colorado  2004  43.886297  Unhealthy for Sensitive Groups
# 55     Colorado  2005  47.264390  Unhealthy for Sensitive Groups
# 64     Colorado  2014  45.739774  Unhealthy for Sensitive Groups
# 65     Colorado  2015  46.558965  Unhealthy for Sensitive Groups
# 66     Colorado  2016  44.646840  Unhealthy for Sensitive Groups
# 67  Connecticut  2006  41.377907  Unhealthy for Sensitive Groups
# 68  Connecticut  2007  44.772305  Unhealthy for Sensitive Groups
# 69  Connecticut  2008  39.681407  Unhealthy for Sensitive Groups
# 70  Connecticut  2009  34.496980  Unhealthy for Sensitive Groups
# 71  Connecticut  2010  37.747815  Unhealthy for Sensitive Groups

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})

df_demographics=df_annual.groupby(['State'])['EPA'].count()
df_demographics.plot.bar(figsize=(40,10))
plt.xlabel('States')
plt.ylabel('Counts of annual air quality measurements')
plt.title('Counts of annual air quality measurements per state')
plt.show()

# %%
# Taking the States that present the same amount of counts of annual air quality measurements
States_EPA=['Arizona', 'California', 'Colorado', 'District Of Columbia', 'Florida', 'Illinois', 'Indiana', 'Louisiana',
            'New York', 'North Carolina', 'Pennsylvania', 'Texas']

# %%
States_df =  df.loc[df['State'].isin(States_EPA)]

# %%
States_df.groupby(['Year','EPA'])['EPA'].count()
# Out:
# Year  EPA
# 2000  Good                              53699
#       Moderate                          13379
#       Unhealthy                           256
#       Unhealthy for Sensitive Groups     2364
#       Very Unhealthy                       42
# 2001  Good                              56235
#       Moderate                          14970
#       Unhealthy                           296
#       Unhealthy for Sensitive Groups     2688
#       Very Unhealthy                       28
# 2002  Good                              57844
#       Moderate                          13068
#       Unhealthy                           594
#       Unhealthy for Sensitive Groups     3246
#       Very Unhealthy                       28
# 2003  Good                              58542
#       Moderate                          11933
#       Unhealthy                           290
#       Unhealthy for Sensitive Groups     2113
#       Very Unhealthy                       68
# 2004  Good                              58896
#       Moderate                          10252
#       Unhealthy                            94
#       Unhealthy for Sensitive Groups     1322
#       Very Unhealthy                        4
# 2005  Good                              60432
#       Moderate                          11972
#       Unhealthy                           164
#       Unhealthy for Sensitive Groups     1918
#       Very Unhealthy                        8
#                                         ...
# 2010  Moderate                           7679
#       Unhealthy                            56
#       Unhealthy for Sensitive Groups      986
# 2011  Good                              68642
#       Moderate                           8314
#       Unhealthy                           122
#       Unhealthy for Sensitive Groups     1556
#       Very Unhealthy                        4
# 2012  Good                              64572
#       Moderate                           7742
#       Unhealthy                           122
#       Unhealthy for Sensitive Groups     1484
#       Very Unhealthy                        4
# 2013  Good                              70820
#       Moderate                           9530
#       Unhealthy                           152
#       Unhealthy for Sensitive Groups     1216
#       Very Unhealthy                        4
# 2014  Good                              64209
#       Moderate                           9608
#       Unhealthy                           196
#       Unhealthy for Sensitive Groups     1358
# 2015  Good                              56830
#       Moderate                           9778
#       Unhealthy                           272
#       Unhealthy for Sensitive Groups     1274
#       Very Unhealthy                        4
# 2016  Good                              13936
#       Moderate                            798
#       Unhealthy for Sensitive Groups        4
# Name: EPA, Length: 81, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 30})

df_year=States_df.groupby(['Year','EPA'])['EPA'].count()
df_year.plot.bar(figsize=(60,30))
plt.xlabel('Year & air quality')
plt.ylabel('Counts of annual air quality measurements')
plt.title('Counts of annual air quality measurements per year')
plt.show()

# %%
States_df.groupby(['Year'])['EPA'].count()
# Out:
# Year
# 2000    69740
# 2001    74217
# 2002    74780
# 2003    72946
# 2004    70568
# 2005    74494
# 2006    77865
# 2007    88401
# 2008    92523
# 2009    79224
# 2010    73104
# 2011    78638
# 2012    73924
# 2013    81722
# 2014    75371
# 2015    68158
# 2016    14738
# Name: EPA, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 30})

df_year=States_df.groupby(['State','EPA'])['EPA'].count()
df_year.plot.bar(figsize=(60,30))
plt.xlabel('Year & air quality')
plt.ylabel('Counts of annual air quality measurements')
plt.title('Counts of annual air quality measurements per year')
plt.show()

# %%
States_df.groupby(['State'])['EPA'].count()
# Out:
# State
# Arizona                  69840
# California              576142
# Colorado                 35188
# District Of Columbia     25696
# Florida                  25918
# Illinois                 50116
# Indiana                  13926
# Louisiana                23874
# New York                 70487
# North Carolina           37126
# Pennsylvania            188892
# Texas                   123208
# Name: EPA, dtype: int64

# %%
CA_df_states=States_df.loc[df['State'] == "California"]

# %%
CA_df_states.groupby(['Year'])['EPA'].count()
# Out:
# Year
# 2000    34790
# 2001    37221
# 2002    38932
# 2003    36858
# 2004    33805
# 2005    34686
# 2006    34177
# 2007    37081
# 2008    41042
# 2009    35700
# 2010    33240
# 2011    37414
# 2012    32948
# 2013    35820
# 2014    34086
# 2015    32842
# 2016     5500
# Name: EPA, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 30})

df_year=CA_df_states.groupby(['Year','EPA'])['EPA'].count()
df_year.plot.bar(figsize=(60,30))
plt.xlabel('Year & air quality')
plt.ylabel('Counts of annual air quality measurements')
plt.title('Counts of annual air quality measurements per year in California')
plt.show()

# %%
SD_df_states = CA_df_states.loc[CA_df_states['County'] == "San Diego"]

# %%
SD_df_states.groupby(['Year'])['EPA'].count()
# Out:
# Year
# 2000    4262
# 2001    4098
# 2002    4320
# 2003    4294
# 2004    4336
# 2005    4182
# 2006    4274
# 2007    4154
# 2008    4104
# 2009    4344
# 2010    1514
# 2011    2170
# 2012    1430
# 2013    1376
# 2014     888
# 2015    1364
# Name: EPA, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 30})

df_year=SD_df_states.groupby(['Year','EPA'])['EPA'].count()
df_year.plot.bar(figsize=(60,30))
plt.xlabel('Year & air quality')
plt.ylabel('Counts of annual air quality measurements')
plt.title('Counts of annual air quality measurements per year in San Diego')
plt.show()

# %%
LA_df_states = CA_df_states.loc[CA_df_states['County'] == "Los Angeles"]

# %%
LA_df_states.groupby(['Year'])['EPA'].count()
# Out:
# Year
# 2000    5600
# 2001    7324
# 2002    6882
# 2003    5500
# 2004    5393
# 2005    5782
# 2006    5700
# 2007    5584
# 2008    5680
# 2009    5190
# 2010    6804
# 2011    5942
# 2012    4290
# 2013    7032
# 2014    5998
# 2015    4680
# Name: EPA, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})

df_year=LA_df_states.groupby(['Year','EPA'])['EPA'].count()
df_year.plot.bar(figsize=(60,30))
plt.xlabel('Year & air quality')
plt.ylabel('Counts of annual air quality measurements')
plt.title('Counts of annual air quality measurements per year in Los Angeles')
plt.show()

# %%
states = df['State'].values

# %%
states
# Out:
# array(['Arizona', 'Arizona', 'Arizona', ..., 'Wyoming', 'Wyoming',
#        'Wyoming'], dtype=object)

# %%
states_set=set(states)

# %%
states_set
# Out:
# {'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Country Of Mexico',
#  'Delaware',
#  'District Of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Missouri',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Virginia',
#  'Washington',
#  'Wisconsin',
#  'Wyoming'}

# %%
len(states_set)
# Out:
# 47
